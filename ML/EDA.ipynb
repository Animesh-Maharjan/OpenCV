# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("datasets/Exam_Score_Prediction.csv")

# %%
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df.sample(10)
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 8568         8569   17   other   b.tech         3.11              81.5
# 9888         9889   24    male    b.com         7.13              60.1
# 19090       19091   17   other      bca         5.26              99.4
# 5679         5680   17   other       ba         3.02              63.9
# 16559       16560   19    male  diploma         4.46              40.8
# 2568         2569   20   other       ba         1.25              79.9
# 6534         6535   24   other     b.sc         5.21              93.4
# 6421         6422   19   other    b.com         7.30              57.6
# 4838         4839   23  female   b.tech         0.44              94.1
# 5109         5110   19   other   b.tech         5.03              44.7
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# 8568              yes          4.9          poor       coaching
# ...

# %%
df.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# 1. Categorical Data

# %% [markdown]
# a. Countplot

# %%
sns.countplot(df["course"])
df["course"].value_counts()
# Out:
# course
# bca        2902
# ba         2896
# b.sc       2878
# b.com      2864
# bba        2836
# diploma    2826
# b.tech     2798
# Name: count, dtype: int64

# %%
sns.countplot(df["internet_access"])
df["internet_access"].value_counts()
# Out:
# internet_access
# yes    16988
# no      3012
# Name: count, dtype: int64

# %%
sns.countplot(df["gender"])
df["gender"].value_counts()
# Out:
# gender
# other     6726
# male      6695
# female    6579
# Name: count, dtype: int64

# %%
sns.countplot(df["study_method"])
df["study_method"].value_counts()
# Out:
# study_method
# self-study       4079
# online videos    4069
# coaching         4036
# group study      3922
# mixed            3894
# Name: count, dtype: int64

# %% [markdown]
# b. piechart

# %%
df["gender"].value_counts().plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 2.Numerical Data

# %% [markdown]
# a. Histogram

# %%
import matplotlib.pyplot as plt

plt.hist(df["exam_score"], bins = 50)
# Out:
# (array([267.,  72.,  95., 103., 120., 157., 165., 211., 222., 259., 305.,
#         343., 417., 362., 394., 440., 502., 492., 541., 510., 567., 558.,
#         567., 606., 594., 668., 626., 586., 608., 618., 615., 623., 549.,
#         535., 559., 530., 500., 463., 403., 396., 377., 313., 318., 282.,
#         261., 220., 171., 157., 139., 614.]),
#  array([ 19.599  ,  21.20702,  22.81504,  24.42306,  26.03108,  27.6391 ,
#          29.24712,  30.85514,  32.46316,  34.07118,  35.6792 ,  37.28722,
#          38.89524,  40.50326,  42.11128,  43.7193 ,  45.32732,  46.93534,
#          48.54336,  50.15138,  51.7594 ,  53.36742,  54.97544,  56.58346,
#          58.19148,  59.7995 ,  61.40752,  63.01554,  64.62356,  66.23158,
#          67.8396 ,  69.44762,  71.05564,  72.66366,  74.27168,  75.8797 ,
#          77.48772,  79.09574,  80.70376,  82.31178,  83.9198 ,  85.52782,
#          87.13584,  88.74386,  90.35188,  91.9599 ,  93.56792,  95.17594,
# ...

# %% [markdown]
# b. Distplot

# %%
sns.distplot(df["exam_score"])
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17036\3534451631.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["exam_score"])
# <Axes: xlabel='exam_score', ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
sns.boxplot(df["exam_score"])
# Out:
# <Axes: ylabel='exam_score'>

# %%
df["exam_score"].min()
# Out:
# np.float64(19.599)

# %%
df["exam_score"].max()
# Out:
# np.float64(100.0)

# %%
df["exam_score"].mean()
# Out:
# np.float64(62.513225)

# %%
df["exam_score"].skew()
# Out:
# np.float64(-0.04905862218606845)

# %%
df["age"].skew()
# Out:
# np.float64(0.0147518099648366)

# %% [markdown]
# # Multi/Bai variate Analysis

# %%
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %% [markdown]
# 1. Scatterplot (Numerical - Numerical)
